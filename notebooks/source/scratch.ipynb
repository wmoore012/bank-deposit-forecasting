# %% [markdown]
# # Research decisions and unresolved checks
#
# The long-history audit finds 60 quarters and identical overlap, but 5,738 TFR records cross the 2012 reporting transition. Keep 2020–2024 until the five-field crosswalk is verified. Examine sources/README.md and growth_outputs/masterclass/history_coverage.csv. Extreme targets are retained without clipping; institution-level causes remain unresolved.
