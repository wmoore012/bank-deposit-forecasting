# %% [markdown]
# # Continue the FDIC experiment
#
# Canonical authoring source: ../../build_masterclass.py. Rebuild both editions, then execute each from the project root. The fixed experiment uses signed growth, insured domestic reporting classes, five features, seed 42, and a reused 2024 holdout. Do not tune to the historical evaluation. See frozen_plan.json, run_summary.json, validation_extremes.csv, and bootstrap_interval.csv. The original two-head work is preserved under experiments/experiment_0/.
